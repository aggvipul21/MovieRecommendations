# %%
#Import dependencies
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

# Import new libraries
# %matplotlib inline
import wordcloud
from wordcloud import WordCloud, STOPWORDS

# %%
# Importing csv files to create dataframe
movie_data = "C:/Users/Lilia/Desktop/Final Project - Local/Data/movies.csv"
movies_df = pd.read_csv(movie_data)
movies_df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
# [62423 rows x 3 columns]

# %%
# Importing csv files to create dataframe
ratings_data = "C:/Users/Lilia/Desktop/Final Project - Local/Data/ratings.csv"
ratings_df = pd.read_csv(ratings_data)
ratings_df
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 25000090  162541    50872     4.5  1240953372
# 25000091  162541    55768     2.5  1240951998
# 25000092  162541    56176     2.0  1240950697
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515
#
# [25000095 rows x 4 columns]

# %%
# Create a wordcloud of the movie titles
movies_df['title'] = movies_df['title'].fillna("").astype('str')
title_corpus = ' '.join(movies_df['title'])
title_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='black', height=2000, width=4000).generate(title_corpus)

# Plot the wordcloud
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud)
plt.axis('off')
plt.show()

# %%
# Get summary statistics of rating
ratings_df['rating'].describe()
# Out:
# count    2.500010e+07
# mean     3.533854e+00
# std      1.060744e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
# Import seaborn library
sns.set_style('whitegrid')
sns.set(font_scale=1.5)


# Display distribution of rating
sns.distplot(ratings_df['rating'].fillna(ratings_df['rating'].median()))

# %%
# Join all 3 files into one dataframe
dataset = pd.merge(movies_df, ratings_df)
# Display 20 movies with highest ratings
dataset[['title','genres','rating']].sort_values('rating', ascending=False).head(20)
# Out:
#                                                      title  \
# 11367437                                Matrix, The (1999)
# 3719204                                   Tombstone (1993)
# 22989199                               Intouchables (2011)
# 22989200                               Intouchables (2011)
# 3719210                                   Tombstone (1993)
# 13916199                                  Gladiator (2000)
# 13916198                                  Gladiator (2000)
# 13916197                                  Gladiator (2000)
# 3719201                                   Tombstone (1993)
# 20769882  Harry Potter and the Order of the Phoenix (2007)
# 22989203                               Intouchables (2011)
# 7217626                                  Unforgiven (1992)
# 3719193                                   Tombstone (1993)
# 13916195                                  Gladiator (2000)
# 11054859                            You've Got Mail (1998)
# 3719187                                   Tombstone (1993)
# 22989198                               Intouchables (2011)
# 22989196                               Intouchables (2011)
# 15855962                             Monsters, Inc. (2001)
# 13916204                                  Gladiator (2000)
#
#                                                genres  rating
# 11367437                       Action|Sci-Fi|Thriller     5.0
# 3719204                          Action|Drama|Western     5.0
# 22989199                                 Comedy|Drama     5.0
# 22989200                                 Comedy|Drama     5.0
# 3719210                          Action|Drama|Western     5.0
# 13916199                       Action|Adventure|Drama     5.0
# 13916198                       Action|Adventure|Drama     5.0
# 13916197                       Action|Adventure|Drama     5.0
# 3719201                          Action|Drama|Western     5.0
# 20769882                 Adventure|Drama|Fantasy|IMAX     5.0
# 22989203                                 Comedy|Drama     5.0
# 7217626                                 Drama|Western     5.0
# 3719193                          Action|Drama|Western     5.0
# 13916195                       Action|Adventure|Drama     5.0
# 11054859                               Comedy|Romance     5.0
# 3719187                          Action|Drama|Western     5.0
# 22989198                                 Comedy|Drama     5.0
# 22989196                                 Comedy|Drama     5.0
# 15855962  Adventure|Animation|Children|Comedy|Fantasy     5.0
# 13916204                       Action|Adventure|Drama     5.0
